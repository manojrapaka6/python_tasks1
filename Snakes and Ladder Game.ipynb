# %%
import random
print('Welcome to Snake and Ladder Game')

player1_position=0
player2_position=0

snakes = {27:5,40:3,43:18,54:31,66:45,76:58,89:53,99:41}
ladders = {4:25,13:46,33:49,42:63,50:69,62:81,74: 92}

def roll_dice():
    return random.randint(1,6)

def checking_snakes_ladders(position):
    if position in snakes:
        return snakes[position]
    elif position in ladders:
        return ladders[position]
    else:
        return position

while player1_position < 100 and player2_position < 100:
    input('Player 1 turns.....Press enter to roll dice..')
    dice_value=roll_dice()
    player1_position += dice_value
    player1_position = checking_snakes_ladders(player1_position)
    print(('Player 1 rolled a dice value of {} and he is in the position of {}').format(dice_value,player1_position))
    
    if player1_position >= 100:
        print('WoW...!!, Player 1 wins the game ')
        break
        
    input('Player 2 turns.....Press enter to roll dice..')
    dice_value=roll_dice()
    player2_position += dice_value
    player2_position = checking_snakes_ladders(player2_position)
    print(('Player 2 rolled a dice value of {} and he is in the position of {}').format(dice_value,player2_position))
    
    if player2_position >= 100:
        print('WoW...!!, Player 2 wins the game ')
# Out:
# Welcome to Snake and Ladder Game
# Player 1 turns.....Press enter to roll dice..
# Player 1 rolled a dice value of 6 and he is in the position of 6
# Player 2 turns.....Press enter to roll dice..
# Player 2 rolled a dice value of 5 and he is in the position of 5
# Player 1 turns.....Press enter to roll dice..
# Player 1 rolled a dice value of 1 and he is in the position of 7
# Player 2 turns.....Press enter to roll dice..
# Player 2 rolled a dice value of 4 and he is in the position of 9
# Player 1 turns.....Press enter to roll dice..
# Player 1 rolled a dice value of 4 and he is in the position of 11
# Player 2 turns.....Press enter to roll dice..
# Player 2 rolled a dice value of 3 and he is in the position of 12
# Player 1 turns.....Press enter to roll dice..
# Player 1 rolled a dice value of 2 and he is in the position of 46
# Player 2 turns.....Press enter to roll dice..
# Player 2 rolled a dice value of 5 and he is in the position of 17
# ...
